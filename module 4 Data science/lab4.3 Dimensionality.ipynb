# %%
# step import necessary libararies
import pandas as pd
import numpy as np

# %%
df.mode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.mode
#
# NameError: name 'df' is not defined

# %%
#step 2 load data
df = pd.read_csv("position_salary.csv", encoding="latin1")
print(df.head())
print(df.info())
print(df.isnull().sum())
# Out:
#                             Position   Location  Gender    Education  \
# 0  QNXT Configuration QA/Testing SME  Ghaziabad  Female  B.Tech/B.E.
# 1           Provider Data Management  New Delhi  Female  B.Tech/B.E.
# 2          Accessibility Engineer QA      Noida  Female          BCA
# 3           Senior Software Engineer  Jalandhar    Male          NaN
# 4         Java Developer/Spring Boot     Meerut    Male          B.A
#
#    Experience (Years)   Salary
# 0                  11  2014510
# 1                  24  1624349
# 2                  25  1926223
# 3                  27  2403560
# 4                  11  1128404
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3467 entries, 0 to 3466
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Position            3448 non-null   object
#  1   Location            3467 non-null   object
#  2   Gender              3443 non-null   object
# ...

# %%
df1=pd.DataFrame({'Name':['ram','lucky',np.NAN]},{'Score':[25,np.NAN,50]})
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df1=pd.DataFrame({'Name':['ram','lucky',np.NAN]},{'Score':[25,np.NAN,50]})
#       2 df1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
# step 3 Data pre-processing
df=pd.get_dummies(df,columns=['Position','Location','Gender','Education'],drop_first=True)
df.head()
# Out:
#    Experience (Years)   Salary  Position_.Net /JavaScript  \
# 0                  11  2014510                      False
# 1                  24  1624349                      False
# 2                  25  1926223                      False
# 3                  27  2403560                      False
# 4                  11  1128404                      False
#
#    Position_.Net Architect  Position_.Net Developer  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
#
#    Position_.Net Developer    Position_.Net Lead/Angular, JavaScript  \
# 0                      False                                   False
# 1                      False                                   False
# 2                      False                                   False
# ...

# %%
features=['Experience (Years)','Salary']
x=df[features]
x
# Out:
#       Experience (Years)   Salary
# 0                     11  2014510
# 1                     24  1624349
# 2                     25  1926223
# 3                     27  2403560
# 4                     11  1128404
# ...                  ...      ...
# 3462                  21   816277
# 3463                  20  1786298
# 3464                  28  1050400
# 3465                  25   764525
# 3466                  24  2252207
#
# [3467 rows x 2 columns]

# %%
df1 = pd.DataFrame({'Name':['ram','lucky',np.NaN],'Score':[25,np.NaN,50]})
df1
# Out:
#     Name  Score
# 0    ram   25.0
# 1  lucky    NaN
# 2    NaN   50.0

# %%
df2=df1.ffill()
df2
# Out:
#     Name  Score
# 0    ram   25.0
# 1  lucky   25.0
# 2  lucky   50.0

# %%
df3=df1.backfill()
df3
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_12940\2409561531.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   df3=df1.backfill()
#     Name  Score
# 0    ram   25.0
# 1  lucky   50.0
# 2    NaN   50.0

# %%
# Find all columns that contain 'Position', 'Gender', and 'Education'
position_cols = [col for col in df.columns if "Position" in col]
gender_cols = [col for col in df.columns if "Gender" in col]
education_cols = [col for col in df.columns if "Education" in col]

# Forward fill all relevant columns
df[position_cols + gender_cols + education_cols] = df[position_cols + gender_cols + education_cols].ffill()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df[["Position","Gender","Education"]]=df[["Position","Gender","Education"]].ffill() #ffill : forward filling
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
print(df.isnull().sum())
# Out:
# Experience (Years)                       0
# Salary                                   0
# Position_.Net /JavaScript                0
# Position_.Net Architect                  0
# Position_.Net Developer                  0
#                                         ..
# Education_LLB                            0
# Education_Mtech                          0
# Education_Not Pursuing Graduation        0
# Education_bachelor of arts               0
# Education_course on computer concepts    0
# Length: 916, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Experience (Years)', 'Salary', 'Position_.Net /JavaScript',
#        'Position_.Net Architect', 'Position_.Net Developer',
#        'Position_.Net Developer  ', 'Position_.Net Lead/Angular, JavaScript',
#        'Position_AML', 'Position_AML Triage Analyst', 'Position_ANDROID',
#        ...
#        'Education_BCA', 'Education_BJMC', 'Education_BTECH',
#        'Education_Diploma', 'Education_HSC', 'Education_LLB',
#        'Education_Mtech', 'Education_Not Pursuing Graduation',
#        'Education_bachelor of arts', 'Education_course on computer concepts'],
#       dtype='object', length=916)

# %%
# Find all columns that contain 'Position', 'Gender', and 'Education'
position_cols = [col for col in df.columns if "Position" in col]
gender_cols = [col for col in df.columns if "Gender" in col]
education_cols = [col for col in df.columns if "Education" in col]

# Forward fill all relevant columns
df[position_cols + gender_cols + education_cols] = df[position_cols + gender_cols + education_cols].ffill()
df
# Out:
#       Experience (Years)   Salary  Position_.Net /JavaScript  \
# 0                     11  2014510                      False
# 1                     24  1624349                      False
# 2                     25  1926223                      False
# 3                     27  2403560                      False
# 4                     11  1128404                      False
# ...                  ...      ...                        ...
# 3462                  21   816277                      False
# 3463                  20  1786298                      False
# 3464                  28  1050400                      False
# 3465                  25   764525                      False
# 3466                  24  2252207                      False
#
#       Position_.Net Architect  Position_.Net Developer  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.scatter(PCA1,PCA2)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA of High Paying Jobs in India")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 plt.scatter(PCA1,PCA2)
#       3 plt.xlabel("Principal Component 1")
#       4 plt.ylabel("Principal Component 2")
#
# NameError: name 'PCA1' is not defined

# %%
# Step-6: Interpretation

# Our features are Experience (in years) and salary, when we observe the scatter plot drawn from PCA says that
# most of times with experience and seniority you can expect hike in your salary

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X = df.select_dtypes(include=['float64', 'int64'])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(X_scaled)

# %%
PCA1 = principal_components[:, 0]
PCA2 = principal_components[:, 1]

# %%
plt.figure(figsize=(10, 10))
plt.scatter(PCA1, PCA2)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA of High Paying Jobs in India")
plt.show()
